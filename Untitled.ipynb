# %%
#1 The markdown will be mainly used for capstone project

# %%
#2
import pandas as pd

# %%
#3
import numpy as np

# %%
#4
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
